# %% [markdown]
# # More on Merging: Geospatial Analysis
# Geospatial analysis is the gathering, display, and manipulation of imagery, GPS, satellite photography and historical data, described explicitly in terms of geographic coordinates or implicitly, in terms of a street address, postal code, or forest stand identifier as they are applied to geographic models. In this recipe, we will analyze such data from the city of Chicago. We will use Pandas to analyze this data.

# %%
import pandas as pd

# %% [markdown]
# ## Landmark Data
# The City of Chicago has a register of landmarks in the city, we can load in this data as a CSV:

# %%
landmarks = pd.read_csv('Individual_Landmarks_-_Map.csv')
landmarks['rowid'] = range(len(landmarks)) #unique number
landmarks[:10]
# Out:
#                                        LANDMARK NAME     ID  \
# 0            Vassar Swiss Underwear Company Building  L-265
# 1                               Mathilde Eliel House  L- 89
# 2                                 Manhattan Building  L-139
# 3  Machinery Hall at Illinois Institute of Techno...  L- 12
# 4                             Melissa Ann Elam House  L- 88
# 5   (Former) Pioneer Trust and Savings Bank Building  L-318
# 6                            DuPont-Whitehouse House  L- 85
# 7                Montgomery Ward & Co. Catalog House  L-149
# 8                              Vorwaerts Turner Hall  L-286
# 9                          City Hall-County Building  L- 71
#
#                               ADDRESS DATE BUILT  \
# 0           2543 - 2545 W Diversey Av        NaN
# 1                     4122 S Ellis Av       1886
# 2                   431 S Dearborn St       1891
# 3                       100 W 33rd St       1901
# 4  4726 S Dr Martin Luther King Jr Dr       1903
# 5                  4000 W. North Ave.       1924
# 6                  3558 S Artesian Av       1876
# 7                    618 W Chicago Av    1907-08
# 8                2431 W. Roosevelt Rd        NaN
# 9   121 N LaSalle St / 118 N Clark St    1905-08
#
#                                ARCHITECT LANDMARK DESIGNATION DATE   LATITUDE  \
# 0                                    NaN                07/30/2008  41.931627
# 1                       Adler & Sullivan                10/02/1991  41.819256
# 2                 William LeBaron Jenney                07/07/1978  41.876066
# 3                Patton, Fisher & Miller                05/26/2004  41.835161
# 4                      Henry L. Newhouse                03/21/1979  41.808530
# 5                       Karl M. Vitzthum                06/06/2012  41.910192
# 6                       Oscar Cobb & Co.                04/16/1996  41.828582
# 7  Richard E. Schmidt, Garden and Martin                05/17/2000  41.897437
# 8                                    NaN                09/03/2009  41.866152
# 9                     Holabird and Roche                01/21/1982  41.883843
#
#    LONGITUDE                         LOCATION  rowid
# 0 -87.692100  (41.9316266084, -87.6921000957)      0
# 1 -87.602788   (41.819255751, -87.6027879992)      1
# 2 -87.628964  (41.8760657234, -87.6289644505)      2
# 3 -87.629221  (41.8351614122, -87.6292212235)      3
# 4 -87.617204   (41.808529769, -87.6172043949)      4
# 5 -87.726617  (41.9101921054, -87.7266173415)      5
# 6 -87.686594  (41.8285816489, -87.6865936818)      6
# 7 -87.643695  (41.8974368676, -87.6436954155)      7
# 8 -87.687247  (41.8661518103, -87.6872469444)      8
# 9 -87.631655  (41.8838425425, -87.6316552814)      9

# %% [markdown]
# The new type of data that we see in this dataset is latitude and longitude data. We use the library `geopy` to do manipulations of such numbers. For example, if we want to calculate the distance between landmarks, we can do the following:

# %%
import geopy.distance

def distance_between(i,j):
    coords_i = landmarks['LATITUDE'][i],landmarks['LONGITUDE'][i]
    coords_j = landmarks['LATITUDE'][j],landmarks['LONGITUDE'][j]
    
    return geopy.distance.geodesic(coords_i, coords_j).mi

distance_between(14,16)
# Out:
# 1.6453285238852118

# %% [markdown]
# Now, suppose, we would like to answer queries that identify nearby landmarks to you. So you provide the function your current latitude and longitude and it returns all landmarks within a distance of you. Naively, we could do the following:

# %%
import datetime

#take a coordinate for me
#find all landmarks within a distance of me
def find_naive(me, landmarks, distance=0.5):
    start = datetime.datetime.now()
    
    rtn = []
    
    N = len(landmarks)
    
    for i in range(N):
        coords_i = landmarks['LATITUDE'][i],landmarks['LONGITUDE'][i]
        
        if geopy.distance.geodesic(me, coords_i).mi < distance:
            rtn.append(i)
    
    print('Elapsed Time find_naive() ', (datetime.datetime.now()-start).total_seconds())
    
    return landmarks.loc[rtn]

#john crerar library: 41.790524,-87.6050427
find_naive((41.790524,-87.6050427), landmarks, distance=0.25)
# Out:
# Elapsed Time find_naive()  0.120969
#                                         LANDMARK NAME     ID  \
# 215  Site of the 1st Self-Sustain Cont. Nuclear Chain  L-184
# 252                 American School of Correspondence  L- 46
#
#                                              ADDRESS DATE BUILT  \
# 215  East Side of S Ellis Ave between 56th & 57th St       1942
# 252                                    850 E 58th St       1907
#
#                                            ARCHITECT  \
# 215  Commern. sculpture,"Nuclear Energy" Henry Moore
# 252                                      Pond & Pond
#
#     LANDMARK DESIGNATION DATE   LATITUDE  LONGITUDE  \
# 215                10/27/1971  41.792162 -87.600870
# 252                04/15/1995  41.789754 -87.604104
#
#                             LOCATION  rowid
# 215  (41.7921621211, -87.6008698951)    215
# 252   (41.789753922, -87.6041036284)    252

# %% [markdown]
# How do we make this search faster? Let's break the city up into sectors and do a sector-by-sector search.
#
# To do so, let's create some dummy columns that bin the latitude and longitude into sectors.

# %%
landmarks['lat_bins'], latbins = pd.cut(x=landmarks['LATITUDE'], labels=False, bins=5, retbins=True)
landmarks['long_bins'], longbins = pd.cut(x=landmarks['LONGITUDE'], labels=False, bins=5, retbins=True)
landmarks[:10]
# Out:
#                                        LANDMARK NAME     ID  \
# 0            Vassar Swiss Underwear Company Building  L-265
# 1                               Mathilde Eliel House  L- 89
# 2                                 Manhattan Building  L-139
# 3  Machinery Hall at Illinois Institute of Techno...  L- 12
# 4                             Melissa Ann Elam House  L- 88
# 5   (Former) Pioneer Trust and Savings Bank Building  L-318
# 6                            DuPont-Whitehouse House  L- 85
# 7                Montgomery Ward & Co. Catalog House  L-149
# 8                              Vorwaerts Turner Hall  L-286
# 9                          City Hall-County Building  L- 71
#
#                               ADDRESS DATE BUILT  \
# 0           2543 - 2545 W Diversey Av        NaN
# 1                     4122 S Ellis Av       1886
# 2                   431 S Dearborn St       1891
# 3                       100 W 33rd St       1901
# 4  4726 S Dr Martin Luther King Jr Dr       1903
# 5                  4000 W. North Ave.       1924
# 6                  3558 S Artesian Av       1876
# 7                    618 W Chicago Av    1907-08
# 8                2431 W. Roosevelt Rd        NaN
# 9   121 N LaSalle St / 118 N Clark St    1905-08
#
#                                ARCHITECT LANDMARK DESIGNATION DATE   LATITUDE  \
# 0                                    NaN                07/30/2008  41.931627
# 1                       Adler & Sullivan                10/02/1991  41.819256
# 2                 William LeBaron Jenney                07/07/1978  41.876066
# 3                Patton, Fisher & Miller                05/26/2004  41.835161
# 4                      Henry L. Newhouse                03/21/1979  41.808530
# 5                       Karl M. Vitzthum                06/06/2012  41.910192
# 6                       Oscar Cobb & Co.                04/16/1996  41.828582
# 7  Richard E. Schmidt, Garden and Martin                05/17/2000  41.897437
# 8                                    NaN                09/03/2009  41.866152
# 9                     Holabird and Roche                01/21/1982  41.883843
#
#    LONGITUDE                         LOCATION  rowid  lat_bins  long_bins
# 0 -87.692100  (41.9316266084, -87.6921000957)      0         3          2
# 1 -87.602788   (41.819255751, -87.6027879992)      1         2          3
# 2 -87.628964  (41.8760657234, -87.6289644505)      2         2          3
# 3 -87.629221  (41.8351614122, -87.6292212235)      3         2          3
# 4 -87.617204   (41.808529769, -87.6172043949)      4         2          3
# 5 -87.726617  (41.9101921054, -87.7266173415)      5         3          1
# 6 -87.686594  (41.8285816489, -87.6865936818)      6         2          2
# 7 -87.643695  (41.8974368676, -87.6436954155)      7         3          3
# 8 -87.687247  (41.8661518103, -87.6872469444)      8         2          2
# 9 -87.631655  (41.8838425425, -87.6316552814)      9         3          3

# %% [markdown]
# We can now do something kind of cool, we can reindex this dataset by the defined bins so we can quickly pull up those landmarks inside the bins. This is how you build an inverted index in Pandas!

# %%
landmark_index = landmarks.groupby(['lat_bins','long_bins'])['rowid'].apply(list)
landmark_index
# Out:
# lat_bins  long_bins
# 0         2                                     [19, 116, 144, 221, 280]
#           3                                                [12, 75, 118]
#           4                            [11, 31, 100, 133, 188, 234, 311]
# 1         1                                                        [142]
#           2                                 [35, 85, 183, 218, 232, 314]
#           3            [26, 32, 45, 58, 73, 77, 79, 103, 132, 146, 17...
#           4              [64, 67, 74, 165, 212, 228, 236, 264, 277, 289]
# 2         1                                          [34, 113, 159, 176]
#           2            [6, 8, 10, 18, 27, 110, 127, 140, 199, 204, 21...
#           3            [1, 2, 3, 4, 37, 39, 43, 60, 61, 65, 68, 72, 8...
# 3         0                            [71, 78, 102, 123, 181, 244, 316]
#           1                                    [5, 42, 54, 93, 115, 167]
#           2            [0, 16, 17, 22, 28, 47, 83, 87, 90, 98, 106, 1...
#           3            [7, 9, 13, 14, 15, 20, 21, 23, 24, 25, 29, 33,...
# 4         0                                               [89, 149, 245]
#           1                 [81, 128, 158, 169, 174, 220, 266, 270, 290]
#           2            [30, 36, 46, 52, 70, 80, 82, 97, 122, 137, 153...
# Name: rowid, dtype: object

# %% [markdown]
# Now, we can write a more sophisticed find function that looks up only those elements in sector that contains your point.

# %%
def find_binned(me, landmarks, index, bins, distance=0.5):
    start = datetime.datetime.now()
    
    rtn = []
    
    #find the long and lat bin
    lat_bin_me = pd.cut(x=pd.Series(me[0]), labels=False, bins=bins[0])[0]
    long_bin_me = pd.cut(x=pd.Series(me[1]),labels=False, bins=bins[1])[0]
    
    for i in index[lat_bin_me, long_bin_me]:
        coords_i = landmarks['LATITUDE'][i],landmarks['LONGITUDE'][i]
        
        if geopy.distance.geodesic(me, coords_i).mi < distance:
            rtn.append(i)
    
    print('Elapsed Time find_binned() ', (datetime.datetime.now()-start).total_seconds())

    return landmarks.loc[rtn]

find_binned((41.790524,-87.6050427), landmarks, landmark_index, (latbins,longbins))
# Out:
# Elapsed Time find_binned()  0.016067
#                                         LANDMARK NAME     ID  \
# 32                           Frederick C. Robie House  L-176
# 73                    Keck-Gottschalk-Keck Apartments  L-126
# 202                      Lorado Taft's Midway Studios  L-192
# 215  Site of the 1st Self-Sustain Cont. Nuclear Chain  L-184
# 243                       Rockefeller Memorial Chapel  L-178
# 252                 American School of Correspondence  L- 46
#
#                                              ADDRESS DATE BUILT  \
# 32                                5757 S Woodlawn Av       1909
# 73                              5551 S University Av       1937
# 202                              6016 S Ingleside Dr  1890-1929
# 215  East Side of S Ellis Ave between 56th & 57th St       1942
# 243                                1156-80 E 59th St    1925-28
# 252                                    850 E 58th St       1907
#
#                                             ARCHITECT  \
# 32                                 Frank Lloyd Wright
# 73                            George and William Keck
# 202  Arch ?, recon:1929;O F Johnson Add:1964;E D Dart
# 215   Commern. sculpture,"Nuclear Energy" Henry Moore
# 243              Bertram Grosvenor Goodhue Associates
# 252                                       Pond & Pond
#
#     LANDMARK DESIGNATION DATE   LATITUDE  LONGITUDE  \
# 32                 09/15/1971  41.789920 -87.595970
# 73                 08/03/1994  41.793551 -87.597704
# 202                12/01/1993  41.785526 -87.603205
# 215                10/27/1971  41.792162 -87.600870
# 243                11/03/2004  41.788526 -87.597044
# 252                04/15/1995  41.789754 -87.604104
#
#                             LOCATION  rowid  lat_bins  long_bins
# 32   (41.7899203248, -87.5959702794)     32         1          3
# 73    (41.793550861, -87.5977036617)     73         1          3
# 202  (41.7855264091, -87.6032052025)    202         1          3
# 215  (41.7921621211, -87.6008698951)    215         1          3
# 243  (41.7885259092, -87.5970443072)    243         1          3
# 252   (41.789753922, -87.6041036284)    252         1          3

# %% [markdown]
# You get exactly the same results, a lot faster!! This technique works well if you are interested in searching for landmarks relatively close to you. The second that you cross bin boundaries it no longer works. Let's try to understand just how accurate binning chicago up into 25 sectors is. To do so, we need to compare the selected values with the binned algorithm with that of the naive algorithm.
#
# We can do this calculation with a join. Luckily Pandas as a join feature called merge which allows us to find where two datasets intersect. In our case, we will use rowid to do this merge.

# %%
result_actual = find_naive((41.790524,-87.6050427), landmarks)
result_heuristic = find_binned((41.790524,-87.6050427), landmarks, landmark_index, (latbins,longbins))

common = result_actual.merge(result_heuristic,on='rowid')

print('Rows in result actual',len(result_actual))
print('Rows in result heuristic',len(result_heuristic))
print('Rows common to both', len(common) )


for dist in range(5,30,5):
    result_actual = find_naive((41.790524,-87.6050427), landmarks, distance=dist/10.0)
    result_heuristic = find_binned((41.790524,-87.6050427), landmarks, landmark_index, (latbins,longbins), distance=dist/10.0)
    common = result_actual.merge(result_heuristic,on='rowid')
    
    print('--- At Distance',dist/10.0,'---')
    tp = len(result_actual)
    print('Missing Rows',len(result_actual) - len(common))
    print()
    print()
# Out:
# Elapsed Time find_naive()  0.154456
# Elapsed Time find_binned()  0.009367
# Rows in result actual 6
# Rows in result heuristic 6
# Rows common to both 6
# Elapsed Time find_naive()  0.111035
# Elapsed Time find_binned()  0.009344
# --- At Distance 0.5 ---
# Missing Rows 0
#
#
# Elapsed Time find_naive()  0.134071
# Elapsed Time find_binned()  0.016006
# --- At Distance 1.0 ---
# Missing Rows 0
#
#
# Elapsed Time find_naive()  0.119813
# Elapsed Time find_binned()  0.011146
# --- At Distance 1.5 ---
# Missing Rows 7
#
#
# Elapsed Time find_naive()  0.099728
# Elapsed Time find_binned()  0.010806
# --- At Distance 2.0 ---
# Missing Rows 12
#
#
# Elapsed Time find_naive()  0.082415
# Elapsed Time find_binned()  0.007749
# --- At Distance 2.5 ---
# Missing Rows 21

# %% [markdown]
# ## Chicago Parks Data
# Now, we're going to try to link this data to Chicago parks data to see how many landmarks are in or very close to Chicago Parks. We have a similar CSV dataset of park facilities and their corresponding latitudes and longitudes:

# %%
parks = pd.read_csv('CPD_Facilities.csv')
parks[:10]
# Out:
#    OBJECTID  PARK_NO                  PARK  \
# 0      1066        9  HAMILTON (ALEXANDER)
# 1      1067        9  HAMILTON (ALEXANDER)
# 2      1068        9  HAMILTON (ALEXANDER)
# 3      1069        9  HAMILTON (ALEXANDER)
# 4      1070        9  HAMILTON (ALEXANDER)
# 5      1071        9  HAMILTON (ALEXANDER)
# 6      1072        9  HAMILTON (ALEXANDER)
# 7      1073        9  HAMILTON (ALEXANDER)
# 8      1074        9  HAMILTON (ALEXANDER)
# 9      1075        9  HAMILTON (ALEXANDER)
#
#                                         the_geom            FACILITY_N  \
# 0   POINT (-87.63769762611605 41.76299921071406)       CULTURAL CENTER
# 1   POINT (-87.63792902987225 41.76281652333733)             GYMNASIUM
# 2   POINT (-87.63691359952921 41.76084938932824)  BASEBALL JR/SOFTBALL
# 3   POINT (-87.63832013450852 41.76200535544225)  BASEBALL JR/SOFTBALL
# 4  POINT (-87.63805916837423 41.760473845106304)  BASEBALL JR/SOFTBALL
# 5   POINT (-87.63674047085885 41.76111277250026)  BASEBALL JR/SOFTBALL
# 6   POINT (-87.6359054976673 41.761924615184846)        POOL (OUTDOOR)
# 7  POINT (-87.63686292205551 41.762619835913384)            PLAYGROUND
# 8   POINT (-87.63660514607702 41.76312824964004)         SPRAY FEATURE
# 9   POINT (-87.63842974936185 41.76119855500161)           BASEBALL SR
#
#   FACILITY_T    X_COORD    Y_COORD  GISOBJID
# 0    SPECIAL -87.637698  41.762999      2494
# 1     INDOOR -87.637929  41.762817      2495
# 2    OUTDOOR -87.636914  41.760849      2496
# 3    OUTDOOR -87.638320  41.762005      2497
# 4    OUTDOOR -87.638059  41.760474      2498
# 5    OUTDOOR -87.636740  41.761113      2499
# 6    OUTDOOR -87.635906  41.761925      2500
# 7    OUTDOOR -87.636863  41.762620      2501
# 8    OUTDOOR -87.636605  41.763128      2502
# 9    OUTDOOR -87.638430  41.761199      2503

# %% [markdown]
# Now, let's bin the data like before. This time let's use finer bins:

# %%
parks['lat_bins'], latbins = pd.cut(x=parks['Y_COORD'], labels=False, bins=25, retbins=True)
parks['long_bins'], longbins = pd.cut(x=parks['X_COORD'], labels=False, bins=25, retbins=True)

landmarks = pd.read_csv('Individual_Landmarks_-_Map.csv')
landmarks['rowid'] = range(len(landmarks))
landmarks[:10]
landmarks['lat_bins'], latbins = pd.cut(x=landmarks['LATITUDE'], labels=False, bins=latbins, retbins=True)
landmarks['long_bins'], longbins = pd.cut(x=landmarks['LONGITUDE'], labels=False, bins=longbins, retbins=True)

parks[:5]
# Out:
#    OBJECTID  PARK_NO                  PARK  \
# 0      1066        9  HAMILTON (ALEXANDER)
# 1      1067        9  HAMILTON (ALEXANDER)
# 2      1068        9  HAMILTON (ALEXANDER)
# 3      1069        9  HAMILTON (ALEXANDER)
# 4      1070        9  HAMILTON (ALEXANDER)
#
#                                         the_geom            FACILITY_N  \
# 0   POINT (-87.63769762611605 41.76299921071406)       CULTURAL CENTER
# 1   POINT (-87.63792902987225 41.76281652333733)             GYMNASIUM
# 2   POINT (-87.63691359952921 41.76084938932824)  BASEBALL JR/SOFTBALL
# 3   POINT (-87.63832013450852 41.76200535544225)  BASEBALL JR/SOFTBALL
# 4  POINT (-87.63805916837423 41.760473845106304)  BASEBALL JR/SOFTBALL
#
#   FACILITY_T    X_COORD    Y_COORD  GISOBJID  lat_bins  long_bins
# 0    SPECIAL -87.637698  41.762999      2494         7         16
# 1     INDOOR -87.637929  41.762817      2495         7         15
# 2    OUTDOOR -87.636914  41.760849      2496         7         16
# 3    OUTDOOR -87.638320  41.762005      2497         7         15
# 4    OUTDOOR -87.638059  41.760474      2498         7         15

# %%
landmarks[:5]
# Out:
#                                        LANDMARK NAME     ID  \
# 0            Vassar Swiss Underwear Company Building  L-265
# 1                               Mathilde Eliel House  L- 89
# 2                                 Manhattan Building  L-139
# 3  Machinery Hall at Illinois Institute of Techno...  L- 12
# 4                             Melissa Ann Elam House  L- 88
#
#                               ADDRESS DATE BUILT                ARCHITECT  \
# 0           2543 - 2545 W Diversey Av        NaN                      NaN
# 1                     4122 S Ellis Av       1886         Adler & Sullivan
# 2                   431 S Dearborn St       1891   William LeBaron Jenney
# 3                       100 W 33rd St       1901  Patton, Fisher & Miller
# 4  4726 S Dr Martin Luther King Jr Dr       1903        Henry L. Newhouse
#
#   LANDMARK DESIGNATION DATE   LATITUDE  LONGITUDE  \
# 0                07/30/2008  41.931627 -87.692100
# 1                10/02/1991  41.819256 -87.602788
# 2                07/07/1978  41.876066 -87.628964
# 3                05/26/2004  41.835161 -87.629221
# 4                03/21/1979  41.808530 -87.617204
#
#                           LOCATION  rowid  lat_bins  long_bins
# 0  (41.9316266084, -87.6921000957)      0        18         11
# 1   (41.819255751, -87.6027879992)      1        11         18
# 2  (41.8760657234, -87.6289644505)      2        15         16
# 3  (41.8351614122, -87.6292212235)      3        12         16
# 4   (41.808529769, -87.6172043949)      4        10         17

# %% [markdown]
# Then, we can apply a join to combine the dataset on rows that have the same bin value:

# %%
parks_and_landmarks = parks.merge(landmarks,on=['lat_bins','long_bins'])
parks_and_landmarks[:5]
# Out:
#    OBJECTID  PARK_NO               PARK  \
# 0      1085      106  HAMLIN (HANNIBAL)
# 1      1086      106  HAMLIN (HANNIBAL)
# 2      1088      106  HAMLIN (HANNIBAL)
# 3      1089      106  HAMLIN (HANNIBAL)
# 4      1090      106  HAMLIN (HANNIBAL)
#
#                                         the_geom                 FACILITY_N  \
# 0   POINT (-87.68030436443362 41.93675714691855)           BASKETBALL COURT
# 1   POINT (-87.67917786526876 41.93654865287884)  FOOTBALL/SOCCER COMBO FLD
# 2   POINT (-87.68032910446819 41.93604307713284)          DOG FRIENDLY AREA
# 3  POINT (-87.67982968492478 41.937481110855266)             FITNESS CENTER
# 4   POINT (-87.68024830957748 41.93708947936905)                  GYMNASIUM
#
#   FACILITY_T    X_COORD    Y_COORD  GISOBJID  lat_bins  ...  \
# 0    OUTDOOR -87.680304  41.936757      2513        19  ...
# 1    OUTDOOR -87.679178  41.936549      2514        19  ...
# 2    OUTDOOR -87.680329  41.936043      2516        19  ...
# 3     INDOOR -87.679830  41.937481      2517        19  ...
# 4     INDOOR -87.680248  41.937089      2518        19  ...
#
#                                        LANDMARK NAME     ID  \
# 0  (Former) Schlitz BreweryTied-House@2159 W.Belmont  L-305
# 1  (Former) Schlitz BreweryTied-House@2159 W.Belmont  L-305
# 2  (Former) Schlitz BreweryTied-House@2159 W.Belmont  L-305
# 3  (Former) Schlitz BreweryTied-House@2159 W.Belmont  L-305
# 4  (Former) Schlitz BreweryTied-House@2159 W.Belmont  L-305
#
#                 ADDRESS DATE BUILT         ARCHITECT  \
# 0  2159 W. Belmont Ave.  1903-1904  Charles Thisslew
# 1  2159 W. Belmont Ave.  1903-1904  Charles Thisslew
# 2  2159 W. Belmont Ave.  1903-1904  Charles Thisslew
# 3  2159 W. Belmont Ave.  1903-1904  Charles Thisslew
# 4  2159 W. Belmont Ave.  1903-1904  Charles Thisslew
#
#   LANDMARK DESIGNATION DATE  LATITUDE  LONGITUDE  \
# 0                07/06/2011  41.93925 -87.683033
# 1                07/06/2011  41.93925 -87.683033
# 2                07/06/2011  41.93925 -87.683033
# 3                07/06/2011  41.93925 -87.683033
# 4                07/06/2011  41.93925 -87.683033
#
#                           LOCATION rowid
# 0  (41.9392502017, -87.6830331298)   248
# 1  (41.9392502017, -87.6830331298)   248
# 2  (41.9392502017, -87.6830331298)   248
# 3  (41.9392502017, -87.6830331298)   248
# 4  (41.9392502017, -87.6830331298)   248
#
# [5 rows x 21 columns]

# %%
def filter(parks_and_landmarks):
    rtn = []
    
    N = len(landmarks)
    
    for i in range(N):
        coords_i = parks_and_landmarks['LATITUDE'][i],parks_and_landmarks['LONGITUDE'][i]
        coords_j = parks_and_landmarks['Y_COORD'][i],parks_and_landmarks['X_COORD'][i]
        
        if geopy.distance.geodesic(coords_j, coords_i).km < 0.1: #100m
            rtn.append(i)
    
    return parks_and_landmarks.loc[rtn]

filter(parks_and_landmarks).groupby(['PARK', 'LANDMARK NAME'])['PARK', 'LANDMARK NAME'].count()
# Out:
# /Users/sanjaykrishnan/Documents/dse-notes/venv/lib/python3.7/site-packages/ipykernel_launcher.py:15: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   from ipykernel import kernelapp as app
#                                                               PARK  \
# PARK             LANDMARK NAME
# CARMEN           (Former) Schlitz Brewery-Tied House             1
#                  Myron Bachman House                             1
# HASAN (ELLIOT)   6901 Oglesby Cooperative Apartment Building     1
# JACKSON (ANDREW) 63rd Street Bathing Pavilion                    3
#
#                                                               LANDMARK NAME
# PARK             LANDMARK NAME
# CARMEN           (Former) Schlitz Brewery-Tied House                      1
#                  Myron Bachman House                                      1
# HASAN (ELLIOT)   6901 Oglesby Cooperative Apartment Building              1
# JACKSON (ANDREW) 63rd Street Bathing Pavilion                             3

# %% [markdown]
# ## Linking to a larger dataset
#
# Suppose, we want to understand what types of businesses are close to the landmarks, we can use the business register from the city of chicago. This particular dataset is significantly larger than the other two (not suprisingly)!

# %%
business = pd.read_csv('Business_Licenses_-_Current_Active.csv')
business[:5]
# Out:
# /Users/sanjaykrishnan/Documents/dse-notes/venv/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                  ID  LICENSE ID  ACCOUNT NUMBER  SITE NUMBER  \
# 0  2664681-20190513     2664681          398472            1
# 1  2664546-20190513     2664546          405793            1
# 2  2699019-20191122     2699019          417235            4
# 3  2699024-20191114     2699024          324455           15
# 4  2699286-20191114     2699286          324457           16
#
#                              LEGAL NAME       DOING BUSINESS AS NAME  \
# 0                 ISLAND PARTY HUT, LLC             ISLAND PARTY HUT
# 1  TINY LOUNGE ON THE RIVERWALK, L.L.C.                    TINY TAPP
# 2                         ROBERT BAUSCH  Bob's Belgian Hot Chocolate
# 3                     Frieder Frotscher                 German Grill
# 4                            Uli Koretz                Sweet Swabian
#
#                     ADDRESS         CITY STATE ZIP CODE  ...  \
# 0  355 E RIVERWALK SOUTH  1      CHICAGO    IL    60601  ...
# 1    55-71 W RIVERWALK  1ST      CHICAGO    IL    60601  ...
# 2              18 S ADDISON  BENSONVILLE    IL    60106  ...
# 3        50 W WASHINGTON ST      CHICAGO    IL    60602  ...
# 4        50 W WASHINGTON ST      CHICAGO    IL    60602  ...
#
#    LICENSE TERM START DATE  LICENSE TERM EXPIRATION DATE  \
# 0               05/13/2019                    05/12/2020
# 1               05/13/2019                    05/12/2020
# 2               11/22/2019                    05/13/2020
# 3               11/14/2019                    05/13/2020
# 4               11/14/2019                    05/13/2020
#
#   LICENSE APPROVED FOR ISSUANCE  DATE ISSUED  LICENSE STATUS  \
# 0                    05/13/2019   05/13/2019             AAI
# 1                    05/13/2019   05/13/2019             AAI
# 2                    11/14/2019   11/22/2019             AAI
# 3                    11/14/2019   11/14/2019             AAI
# 4                    11/14/2019   11/14/2019             AAI
#
#   LICENSE STATUS CHANGE DATE SSA   LATITUDE  LONGITUDE  \
# 0                        NaN NaN  41.887806 -87.617882
# 1                        NaN NaN  41.886952 -87.629875
# 2                        NaN NaN        NaN        NaN
# 3                        NaN NaN  41.883322 -87.629775
# 4                        NaN NaN  41.883322 -87.629775
#
#                                   LOCATION
# 0  (41.88780560547408, -87.61788171685379)
# 1  (41.88695199839048, -87.62987459293426)
# 2                                      NaN
# 3  (41.88332219914999, -87.62977509664286)
# 4  (41.88332219914999, -87.62977509664286)
#
# [5 rows x 34 columns]

# %%
business['lat_bins'], latbins = pd.cut(x=business['LATITUDE'], labels=False, bins=latbins, retbins=True)
business['long_bins'], longbins = pd.cut(x=business['LONGITUDE'], labels=False, bins=longbins, retbins=True)
business[:5]
# Out:
#                  ID  LICENSE ID  ACCOUNT NUMBER  SITE NUMBER  \
# 0  2664681-20190513     2664681          398472            1
# 1  2664546-20190513     2664546          405793            1
# 2  2699019-20191122     2699019          417235            4
# 3  2699024-20191114     2699024          324455           15
# 4  2699286-20191114     2699286          324457           16
#
#                              LEGAL NAME       DOING BUSINESS AS NAME  \
# 0                 ISLAND PARTY HUT, LLC             ISLAND PARTY HUT
# 1  TINY LOUNGE ON THE RIVERWALK, L.L.C.                    TINY TAPP
# 2                         ROBERT BAUSCH  Bob's Belgian Hot Chocolate
# 3                     Frieder Frotscher                 German Grill
# 4                            Uli Koretz                Sweet Swabian
#
#                     ADDRESS         CITY STATE ZIP CODE  ...  \
# 0  355 E RIVERWALK SOUTH  1      CHICAGO    IL    60601  ...
# 1    55-71 W RIVERWALK  1ST      CHICAGO    IL    60601  ...
# 2              18 S ADDISON  BENSONVILLE    IL    60106  ...
# 3        50 W WASHINGTON ST      CHICAGO    IL    60602  ...
# 4        50 W WASHINGTON ST      CHICAGO    IL    60602  ...
#
#    LICENSE APPROVED FOR ISSUANCE  DATE ISSUED LICENSE STATUS  \
# 0                     05/13/2019   05/13/2019            AAI
# 1                     05/13/2019   05/13/2019            AAI
# 2                     11/14/2019   11/22/2019            AAI
# 3                     11/14/2019   11/14/2019            AAI
# 4                     11/14/2019   11/14/2019            AAI
#
#    LICENSE STATUS CHANGE DATE  SSA   LATITUDE  LONGITUDE  \
# 0                         NaN  NaN  41.887806 -87.617882
# 1                         NaN  NaN  41.886952 -87.629875
# 2                         NaN  NaN        NaN        NaN
# 3                         NaN  NaN  41.883322 -87.629775
# 4                         NaN  NaN  41.883322 -87.629775
#
#                                   LOCATION  lat_bins long_bins
# 0  (41.88780560547408, -87.61788171685379)      16.0      17.0
# 1  (41.88695199839048, -87.62987459293426)      15.0      16.0
# 2                                      NaN       NaN       NaN
# 3  (41.88332219914999, -87.62977509664286)      15.0      16.0
# 4  (41.88332219914999, -87.62977509664286)      15.0      16.0
#
# [5 rows x 36 columns]

# %% [markdown]
# Now that we've binned up the business latitudes and longitudes, let's try a bunch of 3-way merges and see how long they take:

# %%
start = datetime.datetime.now()
(parks.merge(landmarks,on=['lat_bins','long_bins'])).merge(business, on=['lat_bins','long_bins'])
print('Elapsed Time join(join(parks, landmarks), business) ', (datetime.datetime.now()-start).total_seconds())
# Out:
# Elapsed Time join(join(parks, landmarks), business)  4.442228

# %%
start = datetime.datetime.now()
(landmarks.merge(business,on=['lat_bins','long_bins'])).merge(parks, on=['lat_bins','long_bins'])
print('Elapsed Time join(join(landmarks, business), parks) ', (datetime.datetime.now()-start).total_seconds())
# Out:
# Elapsed Time join(join(landmarks, business), parks)  1.800296

# %%
start = datetime.datetime.now()
(business.merge(parks,on=['lat_bins','long_bins'])).merge(landmarks, on=['lat_bins','long_bins'])
print('Elapsed Time join(join(parks, business), landmarks) ', (datetime.datetime.now()-start).total_seconds())
# Out:
# Elapsed Time join(join(parks, business), landmarks)  2.952085
